# %% [markdown]
# # Player Market Value Prediction: Applied ML 2025 Final Project
#
# In this notebook, we predict football players' market values using player stats, demographics, and performance data.
# We use the helper functions from `utils.py` to keep our workflow modular and clean.

# %%
# Import libraries and utils
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src import load_all, aggregate_player_stats, get_latest_valuation, merge_player_data, plot_distribution, \
    fillna_and_scale, encode_categorical, scatter_actual_vs_pred, compute_age

# Set pandas options for nicer display
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. Data Loading
#
# First, we load all the relevant tables from the dataset using our utility functions.

# %%
# Load all data as a dictionary of DataFrames
data = load_all()
for name, df in data.items():
    print(f"{name}: {df.shape}")
# Out:
# appearances: (1706806, 13)
# clubs: (439, 17)
# club_games: (148052, 11)
# competitions: (44, 11)
# games: (74026, 23)
# game_events: (1035043, 10)
# game_lineups: (2191911, 10)
# players: (32601, 23)
# player_valuations: (496606, 5)
# transfers: (79646, 10)

# %% [markdown]
# ## 2. Data Preprocessing & Feature Table Creation
#
# We aggregate player stats, get the latest player valuation, and merge everything into a single table.

# %%
# Aggregate stats and get latest valuations
stats = aggregate_player_stats(data['appearances'])
latest_val = get_latest_valuation(data['player_valuations'])

# Merge into main DataFrame
main_df = merge_player_data(data['players'], stats, latest_val)
main_df = main_df.drop(columns='market_value_in_eur_x') \
                 .rename(columns={'market_value_in_eur_y': 'market_value_in_eur'})


display(main_df.head(20))
print(main_df.shape)
# Out:
#     player_id first_name       last_name                   name  last_season  \
# 0          10   Miroslav           Klose         Miroslav Klose         2015
# 1          26      Roman    Weidenfeller     Roman Weidenfeller         2017
# 2          65    Dimitar        Berbatov       Dimitar Berbatov         2015
# 3          77        NaN           Lúcio                  Lúcio         2012
# 4          80        Tom          Starke             Tom Starke         2017
# 5         109        NaN            Dedê                   Dedê         2013
# 6         123  Christoph       Metzelder    Christoph Metzelder         2012
# 7         132      Tomas         Rosicky          Tomas Rosicky         2015
# 8         162       Marc         Ziegler           Marc Ziegler         2012
# 9         215      Roque      Santa Cruz       Roque Santa Cruz         2015
# 10        258     Gerald         Asamoah         Gerald Asamoah         2013
# 11        264      Tamás          Hajnal           Tamás Hajnal         2012
# 12        276     Sladan           Peric           Sladan Peric         2013
# 13        277     Sérgio  da Silva Pinto  Sérgio da Silva Pinto         2013
# 14        299     Fabian           Ernst           Fabian Ernst         2012
# 15        325      Tomas        Ujfalusi         Tomas Ujfalusi         2012
# 16        332   Benjamin          Köhler        Benjamin Köhler         2012
# 17        410  Sebastian            Kehl         Sebastian Kehl         2014
# 18        411      Levan     Kobiashvili      Levan Kobiashvili         2013
# 19        447        Oka         Nikolov            Oka Nikolov         2012
#
#     current_club_id            player_code    country_of_birth  \
# 0               398         miroslav-klose              Poland
# 1                16     roman-weidenfeller             Germany
# 2              1091       dimitar-berbatov            Bulgaria
# 3               506                  lucio              Brazil
# 4                27             tom-starke  East Germany (GDR)
# 5               825                   dede              Brazil
# 6                33    christoph-metzelder             Germany
# 7                11          tomas-rosicky                CSSR
# 8                79           marc-ziegler             Germany
# 9              1084       roque-santa-cruz            Paraguay
# 10               33         gerald-asamoah               Ghana
# 11               79           tamas-hajnal             Hungary
# 12            20100           sladan-peric                 NaN
# 13             3368  sergio-da-silva-pinto            Portugal
# 14            10484           fabian-ernst             Germany
# 15              141         tomas-ujfalusi                CSSR
# 16               24        benjamin-kohler             Germany
# 17               16         sebastian-kehl             Germany
# 18               44      levan-kobiashvili               UdSSR
# 19               24            oka-nikolov             Germany
#
#          city_of_birth country_of_citizenship        date_of_birth  \
# 0                Opole                Germany  1978-06-09 00:00:00
# 1                 Diez                Germany  1980-08-06 00:00:00
# 2          Blagoevgrad               Bulgaria  1981-01-30 00:00:00
# 3             Brasília                 Brazil  1978-05-08 00:00:00
# 4              Freital                Germany  1981-03-18 00:00:00
# 5       Belo Horizonte                 Brazil  1978-04-18 00:00:00
# 6              Haltern                Germany  1980-11-05 00:00:00
# 7                Praha         Czech Republic  1980-10-04 00:00:00
# 8          Blieskastel                Germany  1976-06-13 00:00:00
# 9             Asunción               Paraguay  1981-08-16 00:00:00
# 10             Mampong                Germany  1978-10-03 00:00:00
# 11           Esztergom                Hungary  1981-03-15 00:00:00
# 12                 NaN                Denmark  1982-04-15 00:00:00
# 13   Vila Nova de Gaia                Germany  1980-10-16 00:00:00
# 14            Hannover                Germany                  NaN
# 15             Rýmařov         Czech Republic  1978-03-24 00:00:00
# 16              Berlin                Germany  1980-08-04 00:00:00
# 17               Fulda                Germany  1980-02-13 00:00:00
# 18              Tiflis                Georgia  1977-07-10 00:00:00
# 19  Erbach im Odenwald        North Macedonia  1974-05-25 00:00:00
#
#           sub_position    position   foot  height_in_cm  \
# 0       Centre-Forward      Attack  right         184.0
# 1           Goalkeeper  Goalkeeper   left         190.0
# 2       Centre-Forward      Attack    NaN           NaN
# 3          Centre-Back    Defender    NaN           NaN
# 4           Goalkeeper  Goalkeeper  right         194.0
# 5            Left-Back    Defender    NaN           NaN
# 6          Centre-Back    Defender    NaN           NaN
# 7   Attacking Midfield    Midfield   both         179.0
# 8           Goalkeeper  Goalkeeper  right         193.0
# 9       Centre-Forward      Attack  right         193.0
# 10      Centre-Forward      Attack  right         180.0
# 11  Attacking Midfield    Midfield   both         167.0
# 12         Centre-Back    Defender    NaN           NaN
# 13    Central Midfield    Midfield  right         176.0
# 14  Defensive Midfield    Midfield  right         183.0
# 15         Centre-Back    Defender    NaN           NaN
# 16       Left Midfield    Midfield    NaN           NaN
# 17  Defensive Midfield    Midfield   left         187.0
# 18       Left Midfield    Midfield   left         183.0
# 19          Goalkeeper  Goalkeeper  right         188.0
#
#    contract_expiration_date            agent_name  \
# 0                       NaN  ASBW Sport Marketing
# 1                       NaN      Neubauer 13 GmbH
# 2                       NaN       CSKA-AS-23 Ltd.
# 3                       NaN                   NaN
# 4                       NaN                   IFM
# 5                       NaN      Football Concept
# 6                       NaN                   NaN
# 7                       NaN                   NaN
# 8                       NaN                   NaN
# 9       2023-12-31 00:00:00                   NaN
# 10                      NaN                   NaN
# 11                      NaN                   NaN
# 12                      NaN                   NaN
# 13                      NaN                   NaN
# 14                      NaN                   NaN
# 15                      NaN                   NaN
# 16                      NaN                   NaN
# 17                      NaN                   NaN
# 18                      NaN                   NaN
# 19                      NaN       PRO Profil GmbH
#
#                                             image_url  \
# 0   https://img.a.transfermarkt.technology/portrai...
# 1   https://img.a.transfermarkt.technology/portrai...
# 2   https://img.a.transfermarkt.technology/portrai...
# 3   https://img.a.transfermarkt.technology/portrai...
# 4   https://img.a.transfermarkt.technology/portrai...
# 5   https://img.a.transfermarkt.technology/portrai...
# 6   https://img.a.transfermarkt.technology/portrai...
# 7   https://img.a.transfermarkt.technology/portrai...
# 8   https://img.a.transfermarkt.technology/portrai...
# 9   https://img.a.transfermarkt.technology/portrai...
# 10  https://img.a.transfermarkt.technology/portrai...
# 11  https://img.a.transfermarkt.technology/portrai...
# 12  https://img.a.transfermarkt.technology/portrai...
# 13  https://img.a.transfermarkt.technology/portrai...
# 14  https://img.a.transfermarkt.technology/portrai...
# 15  https://img.a.transfermarkt.technology/portrai...
# 16  https://img.a.transfermarkt.technology/portrai...
# 17  https://img.a.transfermarkt.technology/portrai...
# 18  https://img.a.transfermarkt.technology/portrai...
# 19  https://img.a.transfermarkt.technology/portrai...
#
#                                                   url  \
# 0   https://www.transfermarkt.co.uk/miroslav-klose...
# 1   https://www.transfermarkt.co.uk/roman-weidenfe...
# 2   https://www.transfermarkt.co.uk/dimitar-berbat...
# 3   https://www.transfermarkt.co.uk/lucio/profil/s...
# 4   https://www.transfermarkt.co.uk/tom-starke/pro...
# 5   https://www.transfermarkt.co.uk/dede/profil/sp...
# 6   https://www.transfermarkt.co.uk/christoph-metz...
# 7   https://www.transfermarkt.co.uk/tomas-rosicky/...
# 8   https://www.transfermarkt.co.uk/marc-ziegler/p...
# 9   https://www.transfermarkt.co.uk/roque-santa-cr...
# 10  https://www.transfermarkt.co.uk/gerald-asamoah...
# 11  https://www.transfermarkt.co.uk/tamas-hajnal/p...
# 12  https://www.transfermarkt.co.uk/sladan-peric/p...
# 13  https://www.transfermarkt.co.uk/sergio-da-silv...
# 14  https://www.transfermarkt.co.uk/fabian-ernst/p...
# 15  https://www.transfermarkt.co.uk/tomas-ujfalusi...
# 16  https://www.transfermarkt.co.uk/benjamin-kohle...
# 17  https://www.transfermarkt.co.uk/sebastian-kehl...
# 18  https://www.transfermarkt.co.uk/levan-kobiashv...
# 19  https://www.transfermarkt.co.uk/oka-nikolov/pr...
#
#    current_club_domestic_competition_id  \
# 0                                   IT1
# 1                                    L1
# 2                                   GR1
# 3                                   IT1
# 4                                    L1
# 5                                   TR1
# 6                                    L1
# 7                                   GB1
# 8                                    L1
# 9                                   ES1
# 10                                   L1
# 11                                   L1
# 12                                  DK1
# 13                                  ES1
# 14                                  TR1
# 15                                  TR1
# 16                                   L1
# 17                                   L1
# 18                                   L1
# 19                                   L1
#
#                                     current_club_name  \
# 0                       Società Sportiva Lazio S.p.A.
# 1                                   Borussia Dortmund
# 2   Panthessalonikios Athlitikos Omilos Konstantin...
# 3                              Juventus Football Club
# 4                                   FC Bayern München
# 5                                       Eskisehirspor
# 6                                       FC Schalke 04
# 7                               Arsenal Football Club
# 8           Verein für Bewegungsspiele Stuttgart 1893
# 9                                           Málaga CF
# 10                                      FC Schalke 04
# 11          Verein für Bewegungsspiele Stuttgart 1893
# 12                                   FC Vestsjaelland
# 13                                         Levante UD
# 14                              Kasımpaşa Spor Kulübü
# 15                            Galatasaray Spor Kulübü
# 16                     Eintracht Frankfurt Fußball AG
# 17                                  Borussia Dortmund
# 18                                         Hertha BSC
# 19                     Eintracht Frankfurt Fußball AG
#
#     highest_market_value_in_eur  n_games  total_yellow  total_red  \
# 0                    30000000.0    136.0          19.0        0.0
# 1                     8000000.0    152.0           4.0        2.0
# 2                    34500000.0    122.0          11.0        1.0
# 3                    24500000.0      4.0           0.0        0.0
# 4                     3000000.0     12.0           0.0        0.0
# 5                     9500000.0     41.0           4.0        0.0
# 6                     9500000.0      7.0           0.0        0.0
# 7                    17500000.0     77.0          13.0        0.0
# 8                     1250000.0      NaN           NaN        NaN
# 9                    12000000.0    109.0           3.0        0.0
# 10                    7000000.0     19.0           2.0        0.0
# 11                    6500000.0     24.0           1.0        0.0
# 12                     500000.0      6.0           0.0        0.0
# 13                    3500000.0     66.0          15.0        0.0
# 14                    9000000.0     30.0          10.0        0.0
# 15                   12000000.0      2.0           0.0        0.0
# 16                    2500000.0      7.0           0.0        0.0
# 17                    9000000.0     93.0          11.0        0.0
# 18                    7500000.0     15.0           2.0        0.0
# 19                    2000000.0      9.0           0.0        0.0
#
#     market_value_in_eur
# 0             1000000.0
# 1              750000.0
# 2             1000000.0
# 3              200000.0
# 4              100000.0
# 5              400000.0
# 6             1500000.0
# 7              350000.0
# 8              200000.0
# 9              250000.0
# 10             100000.0
# 11             100000.0
# 12             200000.0
# 13             150000.0
# 14            1500000.0
# 15             300000.0
# 16             150000.0
# 17            1000000.0
# 18             400000.0
# 19             350000.0
# (32601, 26)

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
#
# Let’s examine the distribution of market values, relationships with age, and other interesting patterns.

# %%
# Plot distribution of target variable
plot_distribution(main_df['market_value_in_eur'].dropna(), title="Market Value (EUR) Distribution")

# Example: Plot Market Value vs Age
plt.figure(figsize=(8,4))
plt.scatter(main_df['last_season'], main_df['market_value_in_eur'], alpha=0.5)
plt.xlabel("Last Season")
plt.ylabel("Market Value (EUR)")
plt.title("Market Value vs Last Season")
plt.show()

# Age vs Value
if 'date_of_birth' in main_df.columns:
    main_df['age'] = 2025 - pd.to_datetime(main_df['date_of_birth']).dt.year
    plt.scatter(main_df['age'], main_df['market_value_in_eur'], alpha=0.4)
    plt.xlabel("Age")
    plt.ylabel("Market Value (EUR)")
    plt.title("Market Value vs Age")
    plt.show()

# %% [markdown]
# ## 4. Feature Engineering
#
# We select and prepare the features we want to use for modeling.
# Categorical variables are encoded, numeric features are scaled, and missing values are handled.

# %%
#We need to add an age column, as we would like to use the age as a feature
compute_age(main_df)

# Select features for the model (extend as needed!)
features = [
    'n_games', 'total_yellow', 'total_red',  # From stats
    'age',                                   # Derived
    # Add more features as engineered!
]



cat_features = ['position']  # Example: add position if available

# Handle missing numeric features and scale
X_num = main_df[features].copy()
X_scaled, scaler = fillna_and_scale(X_num, features)

# Encode categorical features if available
if all(col in main_df.columns for col in cat_features):
    X_cat, encoder = encode_categorical(main_df, cat_features)
    # Combine numeric + categorical features
    import numpy as np
    X_full = np.concatenate([X_scaled, X_cat.values], axis=1)
else:
    X_full = X_scaled

# Prepare target variable (log-transform recommended for skew)
y = main_df['market_value_in_eur'].copy()
y = np.log1p(y)  # Use log1p to avoid log(0)

# %% [markdown]
# ## 5. Train/Test Split
#
# We split our data into training and testing sets to fairly evaluate the model's performance.

# %%
from sklearn.model_selection import train_test_split

# Remove rows with missing targets
valid_idx = ~y.isna()
X_full = X_full[valid_idx]
y = y[valid_idx]

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_full, y, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape)
# Out:
# (24862, 9) (6216, 9)

# %% [markdown]
# ## 6. Neural Network Regression
#
# We train a simple neural network to predict player market value.

# %%
import tensorflow as tf
#from tensorflow import tf

# Define a simple MLP model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model (early stopping to avoid overfitting)
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 48.7481 - mae: 5.1864 - val_loss: 1.7763 - val_mae: 1.0215
# Epoch 2/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.5692 - mae: 0.9536 - val_loss: 1.3000 - val_mae: 0.8902
# Epoch 3/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2194 - mae: 0.8649 - val_loss: 1.2271 - val_mae: 0.8667
# Epoch 4/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2123 - mae: 0.8573 - val_loss: 1.1558 - val_mae: 0.8383
# Epoch 5/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1648 - mae: 0.8432 - val_loss: 1.1352 - val_mae: 0.8339
# Epoch 6/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1141 - mae: 0.8263 - val_loss: 1.1382 - val_mae: 0.8400
# Epoch 7/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.1156 - mae: 0.8311 - val_loss: 1.1156 - val_mae: 0.8264
# Epoch 8/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0924 - mae: 0.8240 - val_loss: 1.1248 - val_mae: 0.8335
# Epoch 9/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0945 - mae: 0.8236 - val_loss: 1.1343 - val_mae: 0.8364
# Epoch 10/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0703 - mae: 0.8129 - val_loss: 1.1150 - val_mae: 0.8366
# Epoch 11/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0985 - mae: 0.8251 - val_loss: 1.0835 - val_mae: 0.8147
# Epoch 12/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0998 - mae: 0.8229 - val_loss: 1.0729 - val_mae: 0.8123
# Epoch 13/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0770 - mae: 0.8183 - val_loss: 1.0880 - val_mae: 0.8231
# Epoch 14/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0575 - mae: 0.8082 - val_loss: 1.1496 - val_mae: 0.8439
# Epoch 15/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0507 - mae: 0.8060 - val_loss: 1.0797 - val_mae: 0.8203
# Epoch 16/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0694 - mae: 0.8139 - val_loss: 1.0878 - val_mae: 0.8251
# Epoch 17/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0590 - mae: 0.8133 - val_loss: 1.0589 - val_mae: 0.8119
# Epoch 18/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0563 - mae: 0.8096 - val_loss: 1.0793 - val_mae: 0.8152
# Epoch 19/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0658 - mae: 0.8147 - val_loss: 1.0636 - val_mae: 0.8174
# Epoch 20/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0523 - mae: 0.8092 - val_loss: 1.0410 - val_mae: 0.8037
# Epoch 21/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0481 - mae: 0.8060 - val_loss: 1.0519 - val_mae: 0.8111
# Epoch 22/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0526 - mae: 0.8066 - val_loss: 1.0504 - val_mae: 0.8043
# Epoch 23/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0780 - mae: 0.8175 - val_loss: 1.0492 - val_mae: 0.8106
# Epoch 24/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0863 - mae: 0.8206 - val_loss: 1.0653 - val_mae: 0.8113
# Epoch 25/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0640 - mae: 0.8110 - val_loss: 1.0565 - val_mae: 0.8153
# Epoch 26/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0666 - mae: 0.8162 - val_loss: 1.0488 - val_mae: 0.8088
# Epoch 27/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0637 - mae: 0.8085 - val_loss: 1.0599 - val_mae: 0.8118
# Epoch 28/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0569 - mae: 0.8090 - val_loss: 1.0456 - val_mae: 0.8067
# Epoch 29/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0461 - mae: 0.8047 - val_loss: 1.0379 - val_mae: 0.8031
# Epoch 30/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0673 - mae: 0.8136 - val_loss: 1.0511 - val_mae: 0.8068
# Epoch 31/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0607 - mae: 0.8087 - val_loss: 1.0521 - val_mae: 0.8090
# Epoch 32/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0501 - mae: 0.8076 - val_loss: 1.0442 - val_mae: 0.8013
# Epoch 33/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0627 - mae: 0.8084 - val_loss: 1.0612 - val_mae: 0.8156
# Epoch 34/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0339 - mae: 0.7998 - val_loss: 1.1039 - val_mae: 0.8257
# Epoch 35/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0598 - mae: 0.8092 - val_loss: 1.0376 - val_mae: 0.8016
# Epoch 36/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0535 - mae: 0.8064 - val_loss: 1.0956 - val_mae: 0.8293
# Epoch 37/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0559 - mae: 0.8093 - val_loss: 1.0411 - val_mae: 0.8026
# Epoch 38/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0382 - mae: 0.8042 - val_loss: 1.0483 - val_mae: 0.8105
# Epoch 39/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0556 - mae: 0.8117 - val_loss: 1.0619 - val_mae: 0.8133
# Epoch 40/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0606 - mae: 0.8105 - val_loss: 1.0329 - val_mae: 0.7998
# Epoch 41/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0446 - mae: 0.8085 - val_loss: 1.0400 - val_mae: 0.8007
# Epoch 42/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0366 - mae: 0.8023 - val_loss: 1.0322 - val_mae: 0.8011
# Epoch 43/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0705 - mae: 0.8171 - val_loss: 1.0529 - val_mae: 0.8037
# Epoch 44/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0511 - mae: 0.8060 - val_loss: 1.0727 - val_mae: 0.8116
# Epoch 45/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0624 - mae: 0.8090 - val_loss: 1.0768 - val_mae: 0.8228
# Epoch 46/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0670 - mae: 0.8172 - val_loss: 1.0892 - val_mae: 0.8198
# Epoch 47/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0444 - mae: 0.8054 - val_loss: 1.0904 - val_mae: 0.8238
# Epoch 48/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0510 - mae: 0.8067 - val_loss: 1.0323 - val_mae: 0.8004
# Epoch 49/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0483 - mae: 0.8070 - val_loss: 1.0440 - val_mae: 0.8021
# Epoch 50/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0342 - mae: 0.8057 - val_loss: 1.0552 - val_mae: 0.8091
# Epoch 51/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0556 - mae: 0.8093 - val_loss: 1.0489 - val_mae: 0.8057
# Epoch 52/100
# 622/622 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.0552 - mae: 0.8101 - val_loss: 1.0377 - val_mae: 0.8031

# %% [markdown]
# ## 7. Model Evaluation
#
# We evaluate the model’s predictions using mean absolute error (MAE) and plot actual vs. predicted values.

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# Cell 6: Make predictions, clip extremes, compute metrics

# 1. Predict on the test set (log-space)
y_pred_log = model.predict(X_test).flatten()

# 2. Clip log-predictions to avoid absurd expm1 outputs
max_real_value = 12e7  # €300 million cap
max_log = np.log1p(max_real_value)
y_pred_log_clipped = np.clip(y_pred_log, a_min=0, a_max=max_log)

# 3. Convert back to real-EUR scale
y_test_exp = np.expm1(y_test)
y_pred_exp = np.expm1(y_pred_log_clipped)

# 4. Compute MAE and R^2 on the real-EUR scale
mae_real = mean_absolute_error(y_test_exp, y_pred_exp)
r2_real = r2_score(y_test_exp, y_pred_exp)

# 5. Compute R^2 in log-space
r2_log = r2_score(y_test, y_pred_log)

print(f"Test MAE (EUR scale, clipped): €{mae_real:,.2f}")
print(f"Test R^2 (EUR scale, clipped): {r2_real:.3f}")
print(f"Test R^2 (log1p scale): {r2_log:.3f}")
# Out:
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Test MAE (EUR scale, clipped): €1,182,633.56
# Test R^2 (EUR scale, clipped): 0.314
# Test R^2 (log1p scale): 0.557

# %%
# Cell 7: Scatter plot of Actual vs. Predicted (real-EUR), filtering out extreme predictions

# Only plot points where predicted < €500M, so axes stay readable
limit = 3e8
mask_plot = y_pred_exp < limit

# Apply the same mask to actuals so both arrays align
x_vals = y_test_exp[mask_plot]
y_vals = y_pred_exp[mask_plot]

# Compute min and max for X and Y
x_min, x_max = x_vals.min(), x_vals.max()
y_min, y_max = y_vals.min(), y_vals.max()

# Stretch limits just a tiny bit so points on the border aren’t cut off
x_pad = (x_max / x_min) ** 0.05  
y_pad = (y_max / y_min) ** 0.05

plt.figure(figsize=(8, 6))
plt.scatter(x_vals, y_vals, alpha=0.3)

# Set log–log scale
plt.xscale('log')
plt.yscale('log')

# Set axis limits to exactly cover the data (with a tiny 1% padding)
plt.xlim(x_min / x_pad, x_max * x_pad)
plt.ylim(y_min / y_pad, y_max * y_pad)

# Draw the y = x reference line over that same range
# On a log–log plot, the diagonal line from (min, min) to (max, max) remains straight.
plt.plot(
    [x_min, x_max],
    [x_min, x_max],
    color='green',
    linewidth=1,
    linestyle='--',
    zorder=0
)

plt.xlabel("Actual Market Value (EUR)")
plt.ylabel("Predicted Market Value (EUR, clipped)")
plt.title("Actual vs. Predicted Market Value (axes fit to data)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Hyperparameter Tuning (Quick Example)
#
# Let’s briefly show how to tune the network size for better performance.

# %%
# Example: try different layer sizes
results = []
for size in [16, 32, 64, 128]:
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(size, activation='relu'),
        tf.keras.layers.Dense(size, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    model.fit(X_train, y_train, epochs=20, batch_size=32, verbose=0)
    y_pred = model.predict(X_test).flatten()
    y_pred_exp = np.expm1(y_pred)
    mae = mean_absolute_error(y_test_exp, y_pred_exp)
    results.append((size, mae))

print("Layer size vs MAE:")
for size, mae in results:
    print(f"  {size} units: MAE = €{mae:,.2f}")
# Out:
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# Layer size vs MAE:
#   16 units: MAE = €143,958,853.34
#   32 units: MAE = €31,524,672.34
#   64 units: MAE = €18,818,866.14
#   128 units: MAE = €15,259,251.46

# %% [markdown]
# ## 9. Feature Importance (Optional)
#
# For neural nets, try permutation importance to see which features matter most.

# %% [markdown]
# ## 10. Conclusions
#
# We built a neural network model to predict football player market values using stats and personal data.
# Feel free to extend this with more advanced features, more complex models, or deeper analysis!
